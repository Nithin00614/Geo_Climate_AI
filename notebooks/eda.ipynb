# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/historical_combined.csv")
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year

sns.lineplot(x="year", y="temp_max", hue="city", data=df)
plt.title("Average Max Temperature per Year")
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\nithi\geoclimate-ai\notebooks
